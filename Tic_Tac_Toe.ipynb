# %%
import random
import numpy as np
from numpy import random

board =[' ',' ',' ',' ',' ', ' ',' ',' ', ' ',' ']

win=stop=1;
draw=-1
running=0
player=1
mark='X'

game=running;

def boardf():
    print("1 |2 |3 ")
    print("__|__|__")
    print("4 |5 |6 ")
    print("__|__|__")
    print("7 |8 |9 ")



def boardprint():
    print("            ")
    print("%c | %c | %c" % (board[1],board[2],board[3]))
    print("__|___|__");
    print("%c | %c | %c" % (board[4],board[5],board[6]))
    print("__|___|__");
    print("%c | %c | %c" % (board[7],board[8],board[9]))
    print("__|___|__");
    print("::::::::::::")

def positioncheck(x):
    
    if (board[x]==" "):
        return True
    else:
        return False


def conditioncheck():
    global game
    if(board[1]==board[2] and board[2]==board[3] and board[1]!=' '):
        game=win;
    elif(board[4]==board[5] and board[5]==board[6] and board[4]!=' '):
        game=win;
    elif(board[7]==board[8] and board[8]==board[9] and board[7]!=' '):
        game=win;
    elif(board[1]==board[4] and board[4]==board[7] and board[1]!=' '):
        game=win
    elif(board[2]==board[5] and board[5]==board[8] and board[2]!=' '):
        game=win
    elif(board[3]==board[6] and board[6]==board[9] and board[3]!=' '):
        game=win
    elif(board[1]==board[5] and board[5]==board[9] and board[1]!=' '):
        game=win
    elif(board[3]==board[5] and board[5]==board[7] and board[3]!=' '):
        game=win

    elif(board[1]!=' ' and board[2]!=' ' and board[3]!=' ' and board[4]!=' ' and board[5]!=' ' and board[6]!=' ' and board[7]!=' ' and board[8]!=' ' and board[9]!=' '):    
        game=draw
        
    else:
        game=running;
        
    
        
print("Lets Begin...");
print("player 1 will have X while player 2 will have O")
boardf();
while(game==running):
    if(player % 2 !=0):
        mark='X'
    else:
        mark='O'
  #  select=int(input("Enter position"))
    list = [1,2,3,4,5,6,7,8,9]
    select=random.choice(list)

    if(positioncheck(select)):
        boardprint();
        board[select]=mark
        player=player+1;
        conditioncheck()
            
boardprint()
if(game==draw):
    print("GAME DRAW")
if(game==win):
    player=player-1;
    if(player%2!=0):
        print("X won")
        
    else:
        print("O won")
# Out:
# Lets Begin...
# player 1 will have X while player 2 will have O
# 1 |2 |3
# __|__|__
# 4 |5 |6
# __|__|__
# 7 |8 |9
#
#   |   |
# __|___|__
#   |   |
# __|___|__
#   |   |
# __|___|__
# ::::::::::::
#
#   | X |
# __|___|__
#   |   |
# __|___|__
#   |   |
# __|___|__
# ::::::::::::
#
#   | X |
# __|___|__
#   |   |
# __|___|__
#   |   | O
# __|___|__
# ::::::::::::
#
#   | X |
# __|___|__
# X |   |
# __|___|__
#   |   | O
# __|___|__
# ::::::::::::
#
#   | X | O
# __|___|__
# X |   |
# __|___|__
#   |   | O
# __|___|__
# ::::::::::::
#
#   | X | O
# __|___|__
# X |   |
# __|___|__
#   | X | O
# __|___|__
# ::::::::::::
#
#   | X | O
# __|___|__
# X |   | O
# __|___|__
#   | X | O
# __|___|__
# ::::::::::::
# O won
